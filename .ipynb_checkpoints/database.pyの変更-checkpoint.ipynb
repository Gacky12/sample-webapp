# %%
from assets import models
import pandas as pd

from assets.database import db_session

# %%
df = pd.read_csv('assets/data.csv')

# %%
df.head()
# Out:
#         date  subscribers  reviews
# 0  2019/1/17         2671      194
# 1  2019/1/18         2671      195
# 2  2019/1/19         2674      197
# 3  2019/1/20         2685      199
# 4  2019/1/21         2695      199

# %%
df.iloc[0,0]
# Out:
# '2019/1/17'

# %%
import datetime

# %%
date = datetime.datetime.strptime(df.iloc[0,0],'%Y/%m/%d').date()
date
# Out:
# datetime.date(2019, 1, 17)

# %%
for index, _df in df.iterrows():
    # date型への変更
    date = datetime.datetime.strptime(_df['date'],'%Y/%m/%d').date()
    row = models.Data(date=date, subscribers=_df['subscribers'], reviews=_df['reviews'])
    db_session.add(row)
db_session.commit()
# Out:
# 2024-07-31 23:41:13,507 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-31 23:41:13,520 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,520 INFO sqlalchemy.engine.Engine [generated in 0.00346s (insertmanyvalues) 1/757 (ordered; batch not supported)] ('2019-01-17', 2671, 194, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,522 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,522 INFO sqlalchemy.engine.Engine [insertmanyvalues 2/757 (ordered; batch not supported)] ('2019-01-18', 2671, 195, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,523 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,523 INFO sqlalchemy.engine.Engine [insertmanyvalues 3/757 (ordered; batch not supported)] ('2019-01-19', 2674, 197, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,523 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,523 INFO sqlalchemy.engine.Engine [insertmanyvalues 4/757 (ordered; batch not supported)] ('2019-01-20', 2685, 199, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,524 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,524 INFO sqlalchemy.engine.Engine [insertmanyvalues 5/757 (ordered; batch not supported)] ('2019-01-21', 2695, 199, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,524 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,524 INFO sqlalchemy.engine.Engine [insertmanyvalues 6/757 (ordered; batch not supported)] ('2019-01-22', 2701, 200, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,525 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,525 INFO sqlalchemy.engine.Engine [insertmanyvalues 7/757 (ordered; batch not supported)] ('2019-01-23', 2710, 200, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,525 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,525 INFO sqlalchemy.engine.Engine [insertmanyvalues 8/757 (ordered; batch not supported)] ('2019-01-24', 2718, 201, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,526 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,526 INFO sqlalchemy.engine.Engine [insertmanyvalues 9/757 (ordered; batch not supported)] ('2019-01-25', 2722, 201, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,526 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,526 INFO sqlalchemy.engine.Engine [insertmanyvalues 10/757 (ordered; batch not supported)] ('2019-01-26', 2725, 201, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,526 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,526 INFO sqlalchemy.engine.Engine [insertmanyvalues 11/757 (ordered; batch not supported)] ('2019-01-27', 2734, 202, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,527 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,527 INFO sqlalchemy.engine.Engine [insertmanyvalues 12/757 (ordered; batch not supported)] ('2019-01-28', 2753, 204, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,527 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,527 INFO sqlalchemy.engine.Engine [insertmanyvalues 13/757 (ordered; batch not supported)] ('2019-01-29', 2773, 206, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,527 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,528 INFO sqlalchemy.engine.Engine [insertmanyvalues 14/757 (ordered; batch not supported)] ('2019-01-30', 2785, 208, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,528 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,528 INFO sqlalchemy.engine.Engine [insertmanyvalues 15/757 (ordered; batch not supported)] ('2019-01-31', 2803, 210, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,528 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,529 INFO sqlalchemy.engine.Engine [insertmanyvalues 16/757 (ordered; batch not supported)] ('2019-02-01', 2845, 211, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,529 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,529 INFO sqlalchemy.engine.Engine [insertmanyvalues 17/757 (ordered; batch not supported)] ('2019-02-02', 2847, 213, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,529 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,530 INFO sqlalchemy.engine.Engine [insertmanyvalues 18/757 (ordered; batch not supported)] ('2019-02-03', 2847, 213, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,530 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,531 INFO sqlalchemy.engine.Engine [insertmanyvalues 19/757 (ordered; batch not supported)] ('2019-02-04', 2851, 217, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,531 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,531 INFO sqlalchemy.engine.Engine [insertmanyvalues 20/757 (ordered; batch not supported)] ('2019-02-05', 2852, 218, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,531 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,532 INFO sqlalchemy.engine.Engine [insertmanyvalues 21/757 (ordered; batch not supported)] ('2019-02-06', 2857, 219, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,532 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,532 INFO sqlalchemy.engine.Engine [insertmanyvalues 22/757 (ordered; batch not supported)] ('2019-02-07', 2861, 220, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,532 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,533 INFO sqlalchemy.engine.Engine [insertmanyvalues 23/757 (ordered; batch not supported)] ('2019-02-08', 2865, 222, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,533 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,533 INFO sqlalchemy.engine.Engine [insertmanyvalues 24/757 (ordered; batch not supported)] ('2019-02-09', 2870, 224, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,533 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,534 INFO sqlalchemy.engine.Engine [insertmanyvalues 25/757 (ordered; batch not supported)] ('2019-02-10', 2875, 224, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,534 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,534 INFO sqlalchemy.engine.Engine [insertmanyvalues 26/757 (ordered; batch not supported)] ('2019-02-11', 2892, 227, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,534 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,534 INFO sqlalchemy.engine.Engine [insertmanyvalues 27/757 (ordered; batch not supported)] ('2019-02-12', 2906, 229, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,535 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,535 INFO sqlalchemy.engine.Engine [insertmanyvalues 28/757 (ordered; batch not supported)] ('2019-02-13', 2919, 229, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,535 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,535 INFO sqlalchemy.engine.Engine [insertmanyvalues 29/757 (ordered; batch not supported)] ('2019-02-14', 2942, 231, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,535 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,536 INFO sqlalchemy.engine.Engine [insertmanyvalues 30/757 (ordered; batch not supported)] ('2019-02-15', 2974, 232, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,536 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,536 INFO sqlalchemy.engine.Engine [insertmanyvalues 31/757 (ordered; batch not supported)] ('2019-02-16', 2977, 234, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,537 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,537 INFO sqlalchemy.engine.Engine [insertmanyvalues 32/757 (ordered; batch not supported)] ('2019-02-17', 2978, 234, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,537 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,538 INFO sqlalchemy.engine.Engine [insertmanyvalues 33/757 (ordered; batch not supported)] ('2019-02-18', 2981, 234, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,538 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,538 INFO sqlalchemy.engine.Engine [insertmanyvalues 34/757 (ordered; batch not supported)] ('2019-02-19', 2983, 234, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,538 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,538 INFO sqlalchemy.engine.Engine [insertmanyvalues 35/757 (ordered; batch not supported)] ('2019-02-20', 2984, 237, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,539 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,539 INFO sqlalchemy.engine.Engine [insertmanyvalues 36/757 (ordered; batch not supported)] ('2019-02-21', 2987, 239, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,539 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,539 INFO sqlalchemy.engine.Engine [insertmanyvalues 37/757 (ordered; batch not supported)] ('2019-02-22', 2989, 239, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,540 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,540 INFO sqlalchemy.engine.Engine [insertmanyvalues 38/757 (ordered; batch not supported)] ('2019-02-23', 2993, 241, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,540 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,540 INFO sqlalchemy.engine.Engine [insertmanyvalues 39/757 (ordered; batch not supported)] ('2019-02-24', 2995, 241, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,540 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,541 INFO sqlalchemy.engine.Engine [insertmanyvalues 40/757 (ordered; batch not supported)] ('2019-02-25', 3009, 241, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,541 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,541 INFO sqlalchemy.engine.Engine [insertmanyvalues 41/757 (ordered; batch not supported)] ('2019-02-26', 3014, 243, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,541 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,541 INFO sqlalchemy.engine.Engine [insertmanyvalues 42/757 (ordered; batch not supported)] ('2019-02-27', 3023, 243, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,541 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,542 INFO sqlalchemy.engine.Engine [insertmanyvalues 43/757 (ordered; batch not supported)] ('2019-02-28', 3031, 243, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,542 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,542 INFO sqlalchemy.engine.Engine [insertmanyvalues 44/757 (ordered; batch not supported)] ('2019-03-01', 3052, 244, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,542 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,543 INFO sqlalchemy.engine.Engine [insertmanyvalues 45/757 (ordered; batch not supported)] ('2019-03-02', 3060, 245, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,543 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,543 INFO sqlalchemy.engine.Engine [insertmanyvalues 46/757 (ordered; batch not supported)] ('2019-03-03', 3062, 246, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,543 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,543 INFO sqlalchemy.engine.Engine [insertmanyvalues 47/757 (ordered; batch not supported)] ('2019-03-04', 3063, 249, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,544 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,544 INFO sqlalchemy.engine.Engine [insertmanyvalues 48/757 (ordered; batch not supported)] ('2019-03-05', 3066, 252, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,544 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,544 INFO sqlalchemy.engine.Engine [insertmanyvalues 49/757 (ordered; batch not supported)] ('2019-03-06', 3071, 254, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,544 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,545 INFO sqlalchemy.engine.Engine [insertmanyvalues 50/757 (ordered; batch not supported)] ('2019-03-07', 3074, 255, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,545 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,546 INFO sqlalchemy.engine.Engine [insertmanyvalues 51/757 (ordered; batch not supported)] ('2019-03-08', 3076, 256, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,546 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,546 INFO sqlalchemy.engine.Engine [insertmanyvalues 52/757 (ordered; batch not supported)] ('2019-03-09', 3077, 258, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,547 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,548 INFO sqlalchemy.engine.Engine [insertmanyvalues 53/757 (ordered; batch not supported)] ('2019-03-10', 3080, 258, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,548 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,549 INFO sqlalchemy.engine.Engine [insertmanyvalues 54/757 (ordered; batch not supported)] ('2019-03-11', 3087, 261, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,550 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,550 INFO sqlalchemy.engine.Engine [insertmanyvalues 55/757 (ordered; batch not supported)] ('2019-03-12', 3089, 261, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,551 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,551 INFO sqlalchemy.engine.Engine [insertmanyvalues 56/757 (ordered; batch not supported)] ('2019-03-13', 3093, 262, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,552 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,552 INFO sqlalchemy.engine.Engine [insertmanyvalues 57/757 (ordered; batch not supported)] ('2019-03-14', 3098, 262, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,553 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,553 INFO sqlalchemy.engine.Engine [insertmanyvalues 58/757 (ordered; batch not supported)] ('2019-03-15', 3104, 262, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,554 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,554 INFO sqlalchemy.engine.Engine [insertmanyvalues 59/757 (ordered; batch not supported)] ('2019-03-16', 3112, 262, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,555 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,556 INFO sqlalchemy.engine.Engine [insertmanyvalues 60/757 (ordered; batch not supported)] ('2019-03-17', 3120, 262, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,556 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,557 INFO sqlalchemy.engine.Engine [insertmanyvalues 61/757 (ordered; batch not supported)] ('2019-03-18', 3131, 265, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,557 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,558 INFO sqlalchemy.engine.Engine [insertmanyvalues 62/757 (ordered; batch not supported)] ('2019-03-19', 3142, 266, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,558 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,559 INFO sqlalchemy.engine.Engine [insertmanyvalues 63/757 (ordered; batch not supported)] ('2019-03-20', 3162, 266, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,559 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,560 INFO sqlalchemy.engine.Engine [insertmanyvalues 64/757 (ordered; batch not supported)] ('2019-03-21', 3173, 268, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,560 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,561 INFO sqlalchemy.engine.Engine [insertmanyvalues 65/757 (ordered; batch not supported)] ('2019-03-22', 3180, 269, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,561 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,561 INFO sqlalchemy.engine.Engine [insertmanyvalues 66/757 (ordered; batch not supported)] ('2019-03-23', 3187, 271, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,562 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,562 INFO sqlalchemy.engine.Engine [insertmanyvalues 67/757 (ordered; batch not supported)] ('2019-03-24', 3189, 271, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,563 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,564 INFO sqlalchemy.engine.Engine [insertmanyvalues 68/757 (ordered; batch not supported)] ('2019-03-25', 3196, 274, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,564 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,565 INFO sqlalchemy.engine.Engine [insertmanyvalues 69/757 (ordered; batch not supported)] ('2019-03-26', 3212, 274, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,565 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,565 INFO sqlalchemy.engine.Engine [insertmanyvalues 70/757 (ordered; batch not supported)] ('2019-03-27', 3220, 274, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,566 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,566 INFO sqlalchemy.engine.Engine [insertmanyvalues 71/757 (ordered; batch not supported)] ('2019-03-28', 3226, 275, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,567 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,567 INFO sqlalchemy.engine.Engine [insertmanyvalues 72/757 (ordered; batch not supported)] ('2019-03-29', 3241, 275, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,567 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,567 INFO sqlalchemy.engine.Engine [insertmanyvalues 73/757 (ordered; batch not supported)] ('2019-03-30', 3253, 278, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,569 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,569 INFO sqlalchemy.engine.Engine [insertmanyvalues 74/757 (ordered; batch not supported)] ('2019-03-31', 3255, 278, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,569 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,569 INFO sqlalchemy.engine.Engine [insertmanyvalues 75/757 (ordered; batch not supported)] ('2019-04-01', 3258, 280, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,570 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,570 INFO sqlalchemy.engine.Engine [insertmanyvalues 76/757 (ordered; batch not supported)] ('2019-04-02', 3262, 282, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,571 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,571 INFO sqlalchemy.engine.Engine [insertmanyvalues 77/757 (ordered; batch not supported)] ('2019-04-03', 3264, 282, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,572 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,572 INFO sqlalchemy.engine.Engine [insertmanyvalues 78/757 (ordered; batch not supported)] ('2019-04-04', 3272, 282, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,573 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,573 INFO sqlalchemy.engine.Engine [insertmanyvalues 79/757 (ordered; batch not supported)] ('2019-04-05', 3275, 284, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,574 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,574 INFO sqlalchemy.engine.Engine [insertmanyvalues 80/757 (ordered; batch not supported)] ('2019-04-06', 3276, 287, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,575 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,575 INFO sqlalchemy.engine.Engine [insertmanyvalues 81/757 (ordered; batch not supported)] ('2019-04-07', 3279, 289, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,576 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,576 INFO sqlalchemy.engine.Engine [insertmanyvalues 82/757 (ordered; batch not supported)] ('2019-04-08', 3285, 289, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,576 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,577 INFO sqlalchemy.engine.Engine [insertmanyvalues 83/757 (ordered; batch not supported)] ('2019-04-09', 3300, 291, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,577 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,577 INFO sqlalchemy.engine.Engine [insertmanyvalues 84/757 (ordered; batch not supported)] ('2019-04-10', 3306, 293, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,577 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,578 INFO sqlalchemy.engine.Engine [insertmanyvalues 85/757 (ordered; batch not supported)] ('2019-04-11', 3312, 295, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,578 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,578 INFO sqlalchemy.engine.Engine [insertmanyvalues 86/757 (ordered; batch not supported)] ('2019-04-12', 3319, 295, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,578 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,578 INFO sqlalchemy.engine.Engine [insertmanyvalues 87/757 (ordered; batch not supported)] ('2019-04-13', 3324, 295, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,578 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,579 INFO sqlalchemy.engine.Engine [insertmanyvalues 88/757 (ordered; batch not supported)] ('2019-04-14', 3325, 297, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,579 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,579 INFO sqlalchemy.engine.Engine [insertmanyvalues 89/757 (ordered; batch not supported)] ('2019-04-15', 3329, 298, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,579 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,579 INFO sqlalchemy.engine.Engine [insertmanyvalues 90/757 (ordered; batch not supported)] ('2019-04-16', 3331, 299, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,579 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,580 INFO sqlalchemy.engine.Engine [insertmanyvalues 91/757 (ordered; batch not supported)] ('2019-04-17', 3332, 299, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,580 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,580 INFO sqlalchemy.engine.Engine [insertmanyvalues 92/757 (ordered; batch not supported)] ('2019-04-18', 3333, 299, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,580 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,580 INFO sqlalchemy.engine.Engine [insertmanyvalues 93/757 (ordered; batch not supported)] ('2019-04-19', 3336, 299, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,580 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,581 INFO sqlalchemy.engine.Engine [insertmanyvalues 94/757 (ordered; batch not supported)] ('2019-04-20', 3339, 299, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,581 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,581 INFO sqlalchemy.engine.Engine [insertmanyvalues 95/757 (ordered; batch not supported)] ('2019-04-21', 3343, 300, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,581 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,581 INFO sqlalchemy.engine.Engine [insertmanyvalues 96/757 (ordered; batch not supported)] ('2019-04-22', 3349, 302, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,581 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,582 INFO sqlalchemy.engine.Engine [insertmanyvalues 97/757 (ordered; batch not supported)] ('2019-04-23', 3357, 303, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,582 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,582 INFO sqlalchemy.engine.Engine [insertmanyvalues 98/757 (ordered; batch not supported)] ('2019-04-24', 3370, 303, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,582 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,582 INFO sqlalchemy.engine.Engine [insertmanyvalues 99/757 (ordered; batch not supported)] ('2019-04-25', 3388, 304, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,582 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,583 INFO sqlalchemy.engine.Engine [insertmanyvalues 100/757 (ordered; batch not supported)] ('2019-04-26', 3412, 304, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,583 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,583 INFO sqlalchemy.engine.Engine [insertmanyvalues 101/757 (ordered; batch not supported)] ('2019-04-27', 3437, 305, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,583 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,583 INFO sqlalchemy.engine.Engine [insertmanyvalues 102/757 (ordered; batch not supported)] ('2019-04-28', 3439, 305, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,583 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,584 INFO sqlalchemy.engine.Engine [insertmanyvalues 103/757 (ordered; batch not supported)] ('2019-04-29', 3440, 308, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,584 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,584 INFO sqlalchemy.engine.Engine [insertmanyvalues 104/757 (ordered; batch not supported)] ('2019-04-30', 3447, 309, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,584 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,584 INFO sqlalchemy.engine.Engine [insertmanyvalues 105/757 (ordered; batch not supported)] ('2019-05-01', 3466, 310, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,584 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,585 INFO sqlalchemy.engine.Engine [insertmanyvalues 106/757 (ordered; batch not supported)] ('2019-05-02', 3481, 311, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,585 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,585 INFO sqlalchemy.engine.Engine [insertmanyvalues 107/757 (ordered; batch not supported)] ('2019-05-03', 3504, 314, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,585 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,585 INFO sqlalchemy.engine.Engine [insertmanyvalues 108/757 (ordered; batch not supported)] ('2019-05-04', 3522, 317, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,585 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,585 INFO sqlalchemy.engine.Engine [insertmanyvalues 109/757 (ordered; batch not supported)] ('2019-05-05', 3527, 322, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,586 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,586 INFO sqlalchemy.engine.Engine [insertmanyvalues 110/757 (ordered; batch not supported)] ('2019-05-06', 3533, 324, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,586 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,586 INFO sqlalchemy.engine.Engine [insertmanyvalues 111/757 (ordered; batch not supported)] ('2019-05-07', 3543, 327, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,586 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,586 INFO sqlalchemy.engine.Engine [insertmanyvalues 112/757 (ordered; batch not supported)] ('2019-05-08', 3546, 328, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,587 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,587 INFO sqlalchemy.engine.Engine [insertmanyvalues 113/757 (ordered; batch not supported)] ('2019-05-09', 3555, 330, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,587 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,587 INFO sqlalchemy.engine.Engine [insertmanyvalues 114/757 (ordered; batch not supported)] ('2019-05-10', 3566, 332, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,587 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,588 INFO sqlalchemy.engine.Engine [insertmanyvalues 115/757 (ordered; batch not supported)] ('2019-05-11', 3583, 334, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,588 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,588 INFO sqlalchemy.engine.Engine [insertmanyvalues 116/757 (ordered; batch not supported)] ('2019-05-12', 3594, 335, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,588 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,589 INFO sqlalchemy.engine.Engine [insertmanyvalues 117/757 (ordered; batch not supported)] ('2019-05-13', 3614, 338, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,589 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,589 INFO sqlalchemy.engine.Engine [insertmanyvalues 118/757 (ordered; batch not supported)] ('2019-05-14', 3633, 340, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,589 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,589 INFO sqlalchemy.engine.Engine [insertmanyvalues 119/757 (ordered; batch not supported)] ('2019-05-15', 3647, 344, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,590 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,590 INFO sqlalchemy.engine.Engine [insertmanyvalues 120/757 (ordered; batch not supported)] ('2019-05-16', 3648, 349, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,590 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,590 INFO sqlalchemy.engine.Engine [insertmanyvalues 121/757 (ordered; batch not supported)] ('2019-05-17', 3649, 349, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,590 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,590 INFO sqlalchemy.engine.Engine [insertmanyvalues 122/757 (ordered; batch not supported)] ('2019-05-18', 3651, 351, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,591 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,591 INFO sqlalchemy.engine.Engine [insertmanyvalues 123/757 (ordered; batch not supported)] ('2019-05-19', 3654, 351, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,591 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,591 INFO sqlalchemy.engine.Engine [insertmanyvalues 124/757 (ordered; batch not supported)] ('2019-05-20', 3658, 354, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,591 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,591 INFO sqlalchemy.engine.Engine [insertmanyvalues 125/757 (ordered; batch not supported)] ('2019-05-21', 3671, 354, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,592 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,592 INFO sqlalchemy.engine.Engine [insertmanyvalues 126/757 (ordered; batch not supported)] ('2019-05-22', 3675, 359, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,592 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,592 INFO sqlalchemy.engine.Engine [insertmanyvalues 127/757 (ordered; batch not supported)] ('2019-05-23', 3681, 359, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,592 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,592 INFO sqlalchemy.engine.Engine [insertmanyvalues 128/757 (ordered; batch not supported)] ('2019-05-24', 3694, 361, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,593 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,593 INFO sqlalchemy.engine.Engine [insertmanyvalues 129/757 (ordered; batch not supported)] ('2019-05-25', 3699, 361, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,593 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,593 INFO sqlalchemy.engine.Engine [insertmanyvalues 130/757 (ordered; batch not supported)] ('2019-05-26', 3711, 364, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,593 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,594 INFO sqlalchemy.engine.Engine [insertmanyvalues 131/757 (ordered; batch not supported)] ('2019-05-27', 3722, 368, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,594 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,594 INFO sqlalchemy.engine.Engine [insertmanyvalues 132/757 (ordered; batch not supported)] ('2019-05-28', 3734, 373, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,594 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,595 INFO sqlalchemy.engine.Engine [insertmanyvalues 133/757 (ordered; batch not supported)] ('2019-05-29', 3766, 374, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,595 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,595 INFO sqlalchemy.engine.Engine [insertmanyvalues 134/757 (ordered; batch not supported)] ('2019-05-30', 3781, 375, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,595 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,595 INFO sqlalchemy.engine.Engine [insertmanyvalues 135/757 (ordered; batch not supported)] ('2019-05-31', 3784, 375, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,596 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,596 INFO sqlalchemy.engine.Engine [insertmanyvalues 136/757 (ordered; batch not supported)] ('2019-06-01', 3789, 378, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,596 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,596 INFO sqlalchemy.engine.Engine [insertmanyvalues 137/757 (ordered; batch not supported)] ('2019-06-02', 3790, 379, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,596 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,597 INFO sqlalchemy.engine.Engine [insertmanyvalues 138/757 (ordered; batch not supported)] ('2019-06-03', 3793, 380, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,597 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,597 INFO sqlalchemy.engine.Engine [insertmanyvalues 139/757 (ordered; batch not supported)] ('2019-06-04', 3795, 383, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,597 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,597 INFO sqlalchemy.engine.Engine [insertmanyvalues 140/757 (ordered; batch not supported)] ('2019-06-05', 3808, 385, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,597 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,598 INFO sqlalchemy.engine.Engine [insertmanyvalues 141/757 (ordered; batch not supported)] ('2019-06-06', 3830, 386, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,598 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,598 INFO sqlalchemy.engine.Engine [insertmanyvalues 142/757 (ordered; batch not supported)] ('2019-06-07', 3843, 387, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,598 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,598 INFO sqlalchemy.engine.Engine [insertmanyvalues 143/757 (ordered; batch not supported)] ('2019-06-08', 3857, 390, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,598 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,598 INFO sqlalchemy.engine.Engine [insertmanyvalues 144/757 (ordered; batch not supported)] ('2019-06-09', 3870, 394, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,599 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,599 INFO sqlalchemy.engine.Engine [insertmanyvalues 145/757 (ordered; batch not supported)] ('2019-06-10', 3895, 395, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,599 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,600 INFO sqlalchemy.engine.Engine [insertmanyvalues 146/757 (ordered; batch not supported)] ('2019-06-11', 3919, 397, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,600 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,600 INFO sqlalchemy.engine.Engine [insertmanyvalues 147/757 (ordered; batch not supported)] ('2019-06-12', 3942, 399, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,600 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,601 INFO sqlalchemy.engine.Engine [insertmanyvalues 148/757 (ordered; batch not supported)] ('2019-06-13', 3983, 402, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,601 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,601 INFO sqlalchemy.engine.Engine [insertmanyvalues 149/757 (ordered; batch not supported)] ('2019-06-14', 4022, 404, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,601 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,601 INFO sqlalchemy.engine.Engine [insertmanyvalues 150/757 (ordered; batch not supported)] ('2019-06-15', 4053, 409, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,602 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,602 INFO sqlalchemy.engine.Engine [insertmanyvalues 151/757 (ordered; batch not supported)] ('2019-06-16', 4058, 410, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,602 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,602 INFO sqlalchemy.engine.Engine [insertmanyvalues 152/757 (ordered; batch not supported)] ('2019-06-17', 4063, 414, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,602 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,603 INFO sqlalchemy.engine.Engine [insertmanyvalues 153/757 (ordered; batch not supported)] ('2019-06-18', 4064, 417, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,603 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# ...
# 2024-07-31 23:41:13,928 INFO sqlalchemy.engine.Engine [insertmanyvalues 707/757 (ordered; batch not supported)] ('2020-12-22', 10215, 1708, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,928 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,928 INFO sqlalchemy.engine.Engine [insertmanyvalues 708/757 (ordered; batch not supported)] ('2020-12-23', 10230, 1709, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,929 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,929 INFO sqlalchemy.engine.Engine [insertmanyvalues 709/757 (ordered; batch not supported)] ('2020-12-24', 10236, 1710, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,929 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,929 INFO sqlalchemy.engine.Engine [insertmanyvalues 710/757 (ordered; batch not supported)] ('2020-12-25', 10239, 1713, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,929 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,929 INFO sqlalchemy.engine.Engine [insertmanyvalues 711/757 (ordered; batch not supported)] ('2020-12-26', 10240, 1715, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,929 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,930 INFO sqlalchemy.engine.Engine [insertmanyvalues 712/757 (ordered; batch not supported)] ('2020-12-27', 10242, 1717, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,930 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,930 INFO sqlalchemy.engine.Engine [insertmanyvalues 713/757 (ordered; batch not supported)] ('2020-12-28', 10245, 1719, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,930 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,930 INFO sqlalchemy.engine.Engine [insertmanyvalues 714/757 (ordered; batch not supported)] ('2020-12-29', 10250, 1722, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,930 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,930 INFO sqlalchemy.engine.Engine [insertmanyvalues 715/757 (ordered; batch not supported)] ('2020-12-30', 10258, 1725, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,931 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,931 INFO sqlalchemy.engine.Engine [insertmanyvalues 716/757 (ordered; batch not supported)] ('2020-12-31', 10282, 1729, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,931 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,931 INFO sqlalchemy.engine.Engine [insertmanyvalues 717/757 (ordered; batch not supported)] ('2021-01-01', 10312, 1735, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,931 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,931 INFO sqlalchemy.engine.Engine [insertmanyvalues 718/757 (ordered; batch not supported)] ('2021-01-02', 10331, 1738, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,931 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,932 INFO sqlalchemy.engine.Engine [insertmanyvalues 719/757 (ordered; batch not supported)] ('2021-01-03', 10353, 1741, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,932 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,932 INFO sqlalchemy.engine.Engine [insertmanyvalues 720/757 (ordered; batch not supported)] ('2021-01-04', 10379, 1744, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,932 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,932 INFO sqlalchemy.engine.Engine [insertmanyvalues 721/757 (ordered; batch not supported)] ('2021-01-05', 10406, 1746, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,932 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,932 INFO sqlalchemy.engine.Engine [insertmanyvalues 722/757 (ordered; batch not supported)] ('2021-01-06', 10443, 1748, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,933 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,933 INFO sqlalchemy.engine.Engine [insertmanyvalues 723/757 (ordered; batch not supported)] ('2021-01-07', 10472, 1748, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,933 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,933 INFO sqlalchemy.engine.Engine [insertmanyvalues 724/757 (ordered; batch not supported)] ('2021-01-08', 10511, 1752, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,933 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,933 INFO sqlalchemy.engine.Engine [insertmanyvalues 725/757 (ordered; batch not supported)] ('2021-01-09', 10541, 1755, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,934 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,934 INFO sqlalchemy.engine.Engine [insertmanyvalues 726/757 (ordered; batch not supported)] ('2021-01-10', 10545, 1758, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,934 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,934 INFO sqlalchemy.engine.Engine [insertmanyvalues 727/757 (ordered; batch not supported)] ('2021-01-11', 10549, 1758, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,934 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,934 INFO sqlalchemy.engine.Engine [insertmanyvalues 728/757 (ordered; batch not supported)] ('2021-01-12', 10555, 1763, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,934 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,935 INFO sqlalchemy.engine.Engine [insertmanyvalues 729/757 (ordered; batch not supported)] ('2021-01-13', 10560, 1768, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,935 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,935 INFO sqlalchemy.engine.Engine [insertmanyvalues 730/757 (ordered; batch not supported)] ('2021-01-14', 10561, 1768, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,935 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,935 INFO sqlalchemy.engine.Engine [insertmanyvalues 731/757 (ordered; batch not supported)] ('2021-01-15', 10567, 1770, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,935 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,935 INFO sqlalchemy.engine.Engine [insertmanyvalues 732/757 (ordered; batch not supported)] ('2021-01-16', 10582, 1777, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,935 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,936 INFO sqlalchemy.engine.Engine [insertmanyvalues 733/757 (ordered; batch not supported)] ('2021-01-17', 10585, 1777, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,936 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,936 INFO sqlalchemy.engine.Engine [insertmanyvalues 734/757 (ordered; batch not supported)] ('2021-01-18', 10590, 1780, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,936 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,936 INFO sqlalchemy.engine.Engine [insertmanyvalues 735/757 (ordered; batch not supported)] ('2021-01-19', 10597, 1784, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,936 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,936 INFO sqlalchemy.engine.Engine [insertmanyvalues 736/757 (ordered; batch not supported)] ('2021-01-20', 10610, 1787, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,937 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,937 INFO sqlalchemy.engine.Engine [insertmanyvalues 737/757 (ordered; batch not supported)] ('2021-01-21', 10629, 1790, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,937 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,937 INFO sqlalchemy.engine.Engine [insertmanyvalues 738/757 (ordered; batch not supported)] ('2021-01-22', 10649, 1790, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,937 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,937 INFO sqlalchemy.engine.Engine [insertmanyvalues 739/757 (ordered; batch not supported)] ('2021-01-23', 10663, 1791, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,938 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,938 INFO sqlalchemy.engine.Engine [insertmanyvalues 740/757 (ordered; batch not supported)] ('2021-01-24', 10667, 1794, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,938 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,938 INFO sqlalchemy.engine.Engine [insertmanyvalues 741/757 (ordered; batch not supported)] ('2021-01-25', 10668, 1796, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,938 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,939 INFO sqlalchemy.engine.Engine [insertmanyvalues 742/757 (ordered; batch not supported)] ('2021-01-26', 10671, 1796, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,939 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,939 INFO sqlalchemy.engine.Engine [insertmanyvalues 743/757 (ordered; batch not supported)] ('2021-01-27', 10689, 1800, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,939 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,939 INFO sqlalchemy.engine.Engine [insertmanyvalues 744/757 (ordered; batch not supported)] ('2021-01-28', 10692, 1803, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,939 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,939 INFO sqlalchemy.engine.Engine [insertmanyvalues 745/757 (ordered; batch not supported)] ('2021-01-29', 10699, 1805, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,939 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,940 INFO sqlalchemy.engine.Engine [insertmanyvalues 746/757 (ordered; batch not supported)] ('2021-01-30', 10699, 1805, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,940 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,940 INFO sqlalchemy.engine.Engine [insertmanyvalues 747/757 (ordered; batch not supported)] ('2021-01-31', 10707, 1809, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,940 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,940 INFO sqlalchemy.engine.Engine [insertmanyvalues 748/757 (ordered; batch not supported)] ('2021-02-01', 10712, 1812, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,940 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,940 INFO sqlalchemy.engine.Engine [insertmanyvalues 749/757 (ordered; batch not supported)] ('2021-02-02', 10726, 1813, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,940 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,941 INFO sqlalchemy.engine.Engine [insertmanyvalues 750/757 (ordered; batch not supported)] ('2021-02-03', 10734, 1813, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,985 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,985 INFO sqlalchemy.engine.Engine [insertmanyvalues 751/757 (ordered; batch not supported)] ('2021-02-04', 10743, 1815, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,985 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,986 INFO sqlalchemy.engine.Engine [insertmanyvalues 752/757 (ordered; batch not supported)] ('2021-02-05', 10753, 1820, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,986 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,986 INFO sqlalchemy.engine.Engine [insertmanyvalues 753/757 (ordered; batch not supported)] ('2021-02-06', 10753, 1824, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,986 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,986 INFO sqlalchemy.engine.Engine [insertmanyvalues 754/757 (ordered; batch not supported)] ('2021-02-07', 10756, 1824, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,987 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,987 INFO sqlalchemy.engine.Engine [insertmanyvalues 755/757 (ordered; batch not supported)] ('2021-02-08', 10776, 1826, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,987 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,987 INFO sqlalchemy.engine.Engine [insertmanyvalues 756/757 (ordered; batch not supported)] ('2021-02-09', 10796, 1831, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,988 INFO sqlalchemy.engine.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?) RETURNING id
# 2024-07-31 23:41:13,988 INFO sqlalchemy.engine.Engine [insertmanyvalues 757/757 (ordered; batch not supported)] ('2024-07-27', 22365, 3738, '2024-07-31 23:23:22.486990')
# 2024-07-31 23:41:13,993 INFO sqlalchemy.engine.Engine COMMIT

# %%
def read_data():
    from assets import models
    df = pd.read_csv('assets/data.csv')
    for index, _df in df.iterrows():
        # date型への変更
        date = datetime.datetime.strptime(_df['date'],'%Y/%m/%d').date()
        row = models.Data(date=date, subscribers=_df['subscribers'], reviews=_df['reviews'])
        db_session.add(row)
    db_session.commit()
